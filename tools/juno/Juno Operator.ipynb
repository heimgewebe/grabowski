# %% [markdown]
# # Juno Operator
# Lokaler Read-only-Leitstand für das iPad. Die nächste Zelle aktualisiert Status, Speicher und begrenzte Netzwerkziele.

# %%
from pathlib import Path
from IPython.display import HTML, display
from juno_operator.app import refresh
snapshot, dashboard = refresh(Path.cwd())
display(HTML(dashboard.read_text(encoding='utf-8')))
snapshot.overall_status

# %% [markdown]
# ## Incident-Paket
# Nur bei Bedarf ausführen. Es schreibt ein begrenztes, prüfsummengebundenes Paket in `incidents/` und verändert keine Systemdienste.

# %%
# from juno_operator.app import create_incident
# create_incident(Path.cwd())
